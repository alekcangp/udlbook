# %% [markdown]
# <a href="https://colab.research.google.com/github/alekcangp/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-2_6tphi7
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-2_6tphi7
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=31077467b2fdfe520bfec9db50bca6eff9185c5c7d51e86b409a0336bb35d36a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mxpf6yx_/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = nn.Sequential(
nn.Linear(D_i, D_k),
nn.ReLU(),
nn.Linear(D_k, D_k),
nn.ReLU(),
nn.Linear(D_k, D_o))



def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
    print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.539958, train error 58.22,  test loss 1.643387, test error 65.60
# Epoch     1, train loss 1.302657, train error 47.97,  test loss 1.456883, test error 57.40
# Epoch     2, train loss 1.117267, train error 40.58,  test loss 1.341171, test error 53.60
# Epoch     3, train loss 0.988671, train error 36.20,  test loss 1.267912, test error 49.50
# Epoch     4, train loss 0.851373, train error 29.55,  test loss 1.184696, test error 45.90
# Epoch     5, train loss 0.777829, train error 28.43,  test loss 1.176855, test error 44.50
# Epoch     6, train loss 0.676624, train error 23.75,  test loss 1.106788, test error 42.20
# Epoch     7, train loss 0.626215, train error 21.55,  test loss 1.115431, test error 41.90
# Epoch     8, train loss 0.568259, train error 19.47,  test loss 1.121160, test error 40.90
# Epoch     9, train loss 0.496302, train error 16.90,  test loss 1.069118, test error 38.30
# Epoch    10, train loss 0.386043, train error 10.82,  test loss 1.022860, test error 37.00
# Epoch    11, train loss 0.374273, train error 11.03,  test loss 1.025495, test error 35.30
# Epoch    12, train loss 0.328444, train error 8.57,  test loss 1.057593, test error 35.80
# Epoch    13, train loss 0.297588, train error 7.53,  test loss 1.056156, test error 36.00
# Epoch    14, train loss 0.274767, train error 7.12,  test loss 1.073089, test error 36.20
# Epoch    15, train loss 0.258532, train error 6.32,  test loss 1.097436, test error 36.00
# Epoch    16, train loss 0.235561, train error 5.70,  test loss 1.130731, test error 35.70
# Epoch    17, train loss 0.203738, train error 3.88,  test loss 1.113615, test error 35.90
# Epoch    18, train loss 0.184680, train error 3.32,  test loss 1.125637, test error 36.10
# Epoch    19, train loss 0.174247, train error 2.90,  test loss 1.156209, test error 36.70
# Epoch    20, train loss 0.148059, train error 1.57,  test loss 1.131658, test error 34.70
# Epoch    21, train loss 0.138809, train error 1.43,  test loss 1.148532, test error 35.30
# Epoch    22, train loss 0.130032, train error 1.03,  test loss 1.148891, test error 34.50
# Epoch    23, train loss 0.126100, train error 1.10,  test loss 1.168779, test error 34.40
# Epoch    24, train loss 0.118787, train error 0.90,  test loss 1.182495, test error 34.50
# Epoch    25, train loss 0.112903, train error 0.68,  test loss 1.207340, test error 35.30
# Epoch    26, train loss 0.107911, train error 0.55,  test loss 1.197920, test error 34.60
# Epoch    27, train loss 0.101547, train error 0.45,  test loss 1.221690, test error 34.60
# Epoch    28, train loss 0.097184, train error 0.32,  test loss 1.228764, test error 34.60
# Epoch    29, train loss 0.093362, train error 0.45,  test loss 1.246283, test error 35.00
# Epoch    30, train loss 0.088693, train error 0.20,  test loss 1.249059, test error 34.40
# Epoch    31, train loss 0.084996, train error 0.20,  test loss 1.244150, test error 34.50
# Epoch    32, train loss 0.083334, train error 0.20,  test loss 1.242935, test error 34.50
# Epoch    33, train loss 0.080960, train error 0.20,  test loss 1.255332, test error 34.60
# Epoch    34, train loss 0.079833, train error 0.12,  test loss 1.262559, test error 34.20
# Epoch    35, train loss 0.078582, train error 0.18,  test loss 1.274574, test error 34.70
# Epoch    36, train loss 0.075974, train error 0.18,  test loss 1.275925, test error 34.60
# Epoch    37, train loss 0.074033, train error 0.12,  test loss 1.274022, test error 34.30
# Epoch    38, train loss 0.072874, train error 0.12,  test loss 1.292412, test error 34.20
# Epoch    39, train loss 0.070921, train error 0.10,  test loss 1.288403, test error 34.50
# Epoch    40, train loss 0.069869, train error 0.07,  test loss 1.294269, test error 34.80
# Epoch    41, train loss 0.068864, train error 0.07,  test loss 1.291762, test error 34.10
# Epoch    42, train loss 0.068164, train error 0.07,  test loss 1.300192, test error 34.20
# Epoch    43, train loss 0.067425, train error 0.07,  test loss 1.300133, test error 34.60
# Epoch    44, train loss 0.066722, train error 0.07,  test loss 1.301070, test error 34.50
# Epoch    45, train loss 0.065933, train error 0.07,  test loss 1.302452, test error 34.60
# Epoch    46, train loss 0.065295, train error 0.07,  test loss 1.308623, test error 34.60
# Epoch    47, train loss 0.064629, train error 0.07,  test loss 1.311448, test error 33.90
# Epoch    48, train loss 0.063994, train error 0.07,  test loss 1.315318, test error 34.30
# Epoch    49, train loss 0.063238, train error 0.07,  test loss 1.315594, test error 34.20

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
