# %% [markdown]
# <a href="https://colab.research.google.com/github/alekcangp/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-wus29nz0
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-wus29nz0
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from mnist1d==0.0.2.post16) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.7.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=e56ad3c9b9b74b789faf0ade8a7eb958e9263978c8d599a7f2ebfbae4eb52fa5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-cux5bey5/wheels/d6/38/42/3d2112bc7d915f6195254ac85eb761d922d1b18f52817aa8e2
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero? 50 (act. 45)
# 2.   At what capacity do you expect the first minima of the double descent curve to appear? 20-30 (act. 14)
#
# 3. At what capacity do you expect the maximum of the double descent curve to appear? 50 (act. 45)

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.303135, train error 90.00,  test loss 2.303130, test error 89.25
# Epoch   100, train loss 1.929729, train error 72.38,  test loss 1.790925, test error 70.88
# Epoch   200, train loss 1.910447, train error 71.75,  test loss 1.765841, test error 69.85
# Epoch   300, train loss 1.906034, train error 71.35,  test loss 1.767537, test error 69.45
# Epoch   400, train loss 1.900093, train error 71.75,  test loss 1.745668, test error 68.65
# Epoch   500, train loss 1.898227, train error 71.62,  test loss 1.726190, test error 68.95
# Epoch   600, train loss 1.894067, train error 71.32,  test loss 1.727022, test error 69.38
# Epoch   700, train loss 1.902273, train error 72.53,  test loss 1.727019, test error 69.72
# Epoch   800, train loss 1.892621, train error 71.18,  test loss 1.726884, test error 68.97
# Epoch   900, train loss 1.894375, train error 71.88,  test loss 1.726359, test error 68.43
# Training model with   4 hidden variables
# Epoch     0, train loss 2.291987, train error 88.53,  test loss 2.291812, test error 88.68
# Epoch   100, train loss 1.763259, train error 65.25,  test loss 1.612549, test error 62.55
# Epoch   200, train loss 1.754889, train error 64.65,  test loss 1.621640, test error 62.00
# Epoch   300, train loss 1.749000, train error 65.18,  test loss 1.620852, test error 62.75
# Epoch   400, train loss 1.744957, train error 63.55,  test loss 1.629110, test error 62.70
# Epoch   500, train loss 1.740753, train error 64.20,  test loss 1.616688, test error 62.72
# Epoch   600, train loss 1.740301, train error 64.15,  test loss 1.629146, test error 62.90
# Epoch   700, train loss 1.737923, train error 65.12,  test loss 1.620317, test error 63.22
# Epoch   800, train loss 1.739409, train error 64.62,  test loss 1.634242, test error 63.85
# Epoch   900, train loss 1.737987, train error 64.80,  test loss 1.631924, test error 63.15
# Training model with   6 hidden variables
# Epoch     0, train loss 2.257771, train error 85.60,  test loss 2.244793, test error 84.30
# Epoch   100, train loss 1.687663, train error 60.47,  test loss 1.531389, test error 59.58
# Epoch   200, train loss 1.631135, train error 58.70,  test loss 1.456595, test error 56.28
# Epoch   300, train loss 1.615119, train error 57.67,  test loss 1.441238, test error 55.62
# Epoch   400, train loss 1.602020, train error 56.88,  test loss 1.446502, test error 55.20
# Epoch   500, train loss 1.598573, train error 57.17,  test loss 1.437003, test error 55.62
# Epoch   600, train loss 1.601547, train error 57.08,  test loss 1.440578, test error 55.25
# Epoch   700, train loss 1.595069, train error 56.55,  test loss 1.447806, test error 55.05
# Epoch   800, train loss 1.594291, train error 56.08,  test loss 1.450775, test error 54.62
# Epoch   900, train loss 1.590820, train error 56.10,  test loss 1.442188, test error 55.00
# Training model with   8 hidden variables
# Epoch     0, train loss 2.252352, train error 83.03,  test loss 2.238219, test error 82.55
# Epoch   100, train loss 1.628118, train error 56.83,  test loss 1.479395, test error 57.65
# Epoch   200, train loss 1.578273, train error 55.60,  test loss 1.454432, test error 55.85
# Epoch   300, train loss 1.550571, train error 55.03,  test loss 1.432826, test error 55.97
# Epoch   400, train loss 1.534743, train error 54.60,  test loss 1.436815, test error 55.95
# Epoch   500, train loss 1.527764, train error 54.42,  test loss 1.439290, test error 55.75
# Epoch   600, train loss 1.521730, train error 54.70,  test loss 1.438536, test error 56.00
# Epoch   700, train loss 1.515171, train error 54.12,  test loss 1.434054, test error 55.50
# Epoch   800, train loss 1.509159, train error 53.78,  test loss 1.434333, test error 55.10
# Epoch   900, train loss 1.508961, train error 53.95,  test loss 1.447899, test error 55.53
# Training model with  10 hidden variables
# Epoch     0, train loss 2.236747, train error 83.50,  test loss 2.235485, test error 83.97
# Epoch   100, train loss 1.606039, train error 57.20,  test loss 1.471360, test error 56.67
# Epoch   200, train loss 1.546658, train error 54.97,  test loss 1.467227, test error 56.97
# Epoch   300, train loss 1.520021, train error 53.17,  test loss 1.477675, test error 57.35
# Epoch   400, train loss 1.499751, train error 52.78,  test loss 1.483065, test error 56.45
# Epoch   500, train loss 1.486526, train error 52.05,  test loss 1.490572, test error 56.38
# Epoch   600, train loss 1.481938, train error 52.17,  test loss 1.509860, test error 55.92
# Epoch   700, train loss 1.473871, train error 51.90,  test loss 1.514314, test error 57.05
# Epoch   800, train loss 1.471536, train error 52.05,  test loss 1.523094, test error 56.88
# Epoch   900, train loss 1.472875, train error 51.75,  test loss 1.529493, test error 57.22
# Training model with  14 hidden variables
# Epoch     0, train loss 2.256775, train error 85.45,  test loss 2.253686, test error 85.55
# Epoch   100, train loss 1.430772, train error 49.45,  test loss 1.343717, test error 49.67
# Epoch   200, train loss 1.357203, train error 45.97,  test loss 1.351096, test error 49.55
# Epoch   300, train loss 1.321766, train error 44.58,  test loss 1.342716, test error 48.28
# Epoch   400, train loss 1.300399, train error 44.25,  test loss 1.363572, test error 49.08
# Epoch   500, train loss 1.288186, train error 43.40,  test loss 1.357847, test error 49.28
# Epoch   600, train loss 1.285383, train error 43.75,  test loss 1.396396, test error 51.00
# Epoch   700, train loss 1.272037, train error 42.72,  test loss 1.397908, test error 50.17
# Epoch   800, train loss 1.268472, train error 43.22,  test loss 1.412086, test error 50.35
# Epoch   900, train loss 1.263132, train error 43.80,  test loss 1.417998, test error 49.85
# Training model with  18 hidden variables
# Epoch     0, train loss 2.212450, train error 81.62,  test loss 2.178499, test error 80.30
# Epoch   100, train loss 1.319921, train error 43.55,  test loss 1.326877, test error 49.60
# Epoch   200, train loss 1.243328, train error 41.50,  test loss 1.353457, test error 48.62
# Epoch   300, train loss 1.199278, train error 39.55,  test loss 1.379303, test error 49.65
# Epoch   400, train loss 1.175546, train error 39.53,  test loss 1.424459, test error 50.12
# Epoch   500, train loss 1.160655, train error 39.95,  test loss 1.463613, test error 51.25
# Epoch   600, train loss 1.140079, train error 38.60,  test loss 1.495921, test error 51.20
# Epoch   700, train loss 1.136871, train error 37.90,  test loss 1.508968, test error 50.67
# Epoch   800, train loss 1.126986, train error 38.65,  test loss 1.500804, test error 51.10
# Epoch   900, train loss 1.119530, train error 38.10,  test loss 1.526177, test error 51.50
# Training model with  22 hidden variables
# Epoch     0, train loss 2.228083, train error 83.32,  test loss 2.222346, test error 82.30
# Epoch   100, train loss 1.267715, train error 42.00,  test loss 1.342483, test error 49.90
# Epoch   200, train loss 1.137461, train error 37.35,  test loss 1.401425, test error 49.90
# Epoch   300, train loss 1.076611, train error 36.35,  test loss 1.476749, test error 50.00
# Epoch   400, train loss 1.036131, train error 34.47,  test loss 1.544564, test error 49.58
# Epoch   500, train loss 1.015911, train error 33.88,  test loss 1.624045, test error 50.15
# Epoch   600, train loss 0.999354, train error 33.65,  test loss 1.669947, test error 51.47
# Epoch   700, train loss 0.976067, train error 32.88,  test loss 1.719341, test error 52.30
# Epoch   800, train loss 0.974495, train error 32.60,  test loss 1.762177, test error 51.97
# Epoch   900, train loss 0.956860, train error 31.93,  test loss 1.838182, test error 53.05
# Training model with  26 hidden variables
# Epoch     0, train loss 2.093907, train error 78.32,  test loss 2.040057, test error 76.55
# Epoch   100, train loss 1.195883, train error 39.25,  test loss 1.307445, test error 48.25
# Epoch   200, train loss 1.025580, train error 33.47,  test loss 1.444660, test error 49.10
# Epoch   300, train loss 0.959975, train error 31.47,  test loss 1.610820, test error 52.38
# Epoch   400, train loss 0.918886, train error 31.07,  test loss 1.710089, test error 51.72
# Epoch   500, train loss 0.895224, train error 29.50,  test loss 1.795955, test error 52.60
# Epoch   600, train loss 0.866598, train error 29.03,  test loss 1.877663, test error 53.15
# Epoch   700, train loss 0.847278, train error 27.95,  test loss 1.953777, test error 53.90
# Epoch   800, train loss 0.840262, train error 27.65,  test loss 1.986647, test error 53.22
# Epoch   900, train loss 0.821797, train error 27.88,  test loss 2.045927, test error 54.22
# Training model with  30 hidden variables
# Epoch     0, train loss 2.147340, train error 80.93,  test loss 2.114834, test error 81.25
# Epoch   100, train loss 1.113426, train error 36.75,  test loss 1.378565, test error 50.03
# Epoch   200, train loss 0.936982, train error 30.45,  test loss 1.554078, test error 50.95
# Epoch   300, train loss 0.839847, train error 28.05,  test loss 1.778514, test error 52.60
# Epoch   400, train loss 0.763990, train error 25.57,  test loss 1.947288, test error 52.70
# Epoch   500, train loss 0.732625, train error 24.72,  test loss 2.104542, test error 53.17
# Epoch   600, train loss 0.714902, train error 24.55,  test loss 2.247902, test error 54.25
# Epoch   700, train loss 0.694089, train error 23.85,  test loss 2.355703, test error 54.00
# Epoch   800, train loss 0.654772, train error 22.57,  test loss 2.463622, test error 54.30
# Epoch   900, train loss 0.658769, train error 22.43,  test loss 2.575866, test error 55.28
# Training model with  35 hidden variables
# Epoch     0, train loss 2.060242, train error 78.53,  test loss 2.013245, test error 77.78
# Epoch   100, train loss 1.005698, train error 32.68,  test loss 1.397773, test error 49.92
# Epoch   200, train loss 0.779534, train error 26.00,  test loss 1.693249, test error 51.00
# Epoch   300, train loss 0.662387, train error 22.03,  test loss 2.083829, test error 53.95
# Epoch   400, train loss 0.567241, train error 19.20,  test loss 2.460541, test error 54.95
# Epoch   500, train loss 0.488461, train error 16.10,  test loss 2.878346, test error 56.75
# Epoch   600, train loss 0.481002, train error 17.03,  test loss 3.278462, test error 56.62
# Epoch   700, train loss 0.450549, train error 15.65,  test loss 3.561024, test error 55.08
# Epoch   800, train loss 0.439970, train error 15.28,  test loss 3.909119, test error 56.65
# Epoch   900, train loss 0.432573, train error 15.30,  test loss 4.307076, test error 57.92
# Training model with  40 hidden variables
# Epoch     0, train loss 2.107439, train error 78.25,  test loss 2.081977, test error 78.47
# Epoch   100, train loss 0.927920, train error 30.75,  test loss 1.456992, test error 50.88
# Epoch   200, train loss 0.679552, train error 22.75,  test loss 1.910833, test error 52.25
# Epoch   300, train loss 0.548706, train error 19.53,  test loss 2.555406, test error 54.92
# Epoch   400, train loss 0.427347, train error 14.30,  test loss 3.239466, test error 56.10
# Epoch   500, train loss 0.379984, train error 12.93,  test loss 3.865283, test error 56.33
# Epoch   600, train loss 0.412421, train error 14.93,  test loss 4.493061, test error 56.12
# Epoch   700, train loss 0.347870, train error 12.68,  test loss 5.136647, test error 56.80
# Epoch   800, train loss 0.279961, train error 9.88,  test loss 5.809774, test error 57.00
# Epoch   900, train loss 0.328726, train error 11.72,  test loss 6.229151, test error 57.72
# Training model with  45 hidden variables
# Epoch     0, train loss 2.096461, train error 77.75,  test loss 2.054528, test error 77.30
# Epoch   100, train loss 0.855026, train error 27.20,  test loss 1.538491, test error 51.72
# Epoch   200, train loss 0.517026, train error 16.07,  test loss 2.205769, test error 54.60
# Epoch   300, train loss 0.346772, train error 10.82,  test loss 3.220731, test error 55.97
# Epoch   400, train loss 0.238856, train error 7.72,  test loss 4.381462, test error 56.88
# Epoch   500, train loss 0.128960, train error 3.25,  test loss 5.769581, test error 57.53
# Epoch   600, train loss 0.099338, train error 2.72,  test loss 7.342815, test error 58.47
# Epoch   700, train loss 0.017145, train error 0.00,  test loss 8.335287, test error 58.28
# Epoch   800, train loss 0.010647, train error 0.00,  test loss 9.148096, test error 58.30
# Epoch   900, train loss 0.007781, train error 0.00,  test loss 9.751594, test error 58.33
# Training model with  50 hidden variables
# Epoch     0, train loss 2.055500, train error 76.25,  test loss 1.995209, test error 75.30
# Epoch   100, train loss 0.706704, train error 22.43,  test loss 1.631671, test error 50.20
# Epoch   200, train loss 0.352688, train error 10.88,  test loss 2.764869, test error 53.25
# Epoch   300, train loss 0.145074, train error 3.25,  test loss 4.330338, test error 54.85
# Epoch   400, train loss 0.028024, train error 0.00,  test loss 5.926126, test error 55.92
# Epoch   500, train loss 0.013039, train error 0.00,  test loss 6.863850, test error 55.70
# Epoch   600, train loss 0.008235, train error 0.00,  test loss 7.484890, test error 55.58
# Epoch   700, train loss 0.005967, train error 0.00,  test loss 7.947573, test error 55.58
# Epoch   800, train loss 0.004603, train error 0.00,  test loss 8.317333, test error 55.53
# Epoch   900, train loss 0.003713, train error 0.00,  test loss 8.627647, test error 55.60
# Training model with  55 hidden variables
# Epoch     0, train loss 2.056370, train error 76.88,  test loss 1.993378, test error 77.07
# Epoch   100, train loss 0.633000, train error 19.53,  test loss 1.571817, test error 49.70
# Epoch   200, train loss 0.228946, train error 5.82,  test loss 2.856272, test error 53.20
# Epoch   300, train loss 0.039556, train error 0.00,  test loss 4.457530, test error 53.62
# Epoch   400, train loss 0.014604, train error 0.00,  test loss 5.420435, test error 53.62
# Epoch   500, train loss 0.008174, train error 0.00,  test loss 5.990099, test error 53.85
# Epoch   600, train loss 0.005630, train error 0.00,  test loss 6.410856, test error 53.92
# Epoch   700, train loss 0.004233, train error 0.00,  test loss 6.735537, test error 53.88
# Epoch   800, train loss 0.003360, train error 0.00,  test loss 7.003936, test error 54.10
# Epoch   900, train loss 0.002745, train error 0.00,  test loss 7.228721, test error 54.05
# Training model with  60 hidden variables
# Epoch     0, train loss 2.096226, train error 77.60,  test loss 2.082068, test error 78.43
# Epoch   100, train loss 0.557328, train error 16.22,  test loss 1.680323, test error 50.20
# Epoch   200, train loss 0.123325, train error 1.57,  test loss 3.126067, test error 53.17
# Epoch   300, train loss 0.021130, train error 0.00,  test loss 4.489761, test error 53.58
# Epoch   400, train loss 0.009972, train error 0.00,  test loss 5.166590, test error 53.90
# Epoch   500, train loss 0.006116, train error 0.00,  test loss 5.600588, test error 53.92
# Epoch   600, train loss 0.004350, train error 0.00,  test loss 5.926390, test error 53.88
# Epoch   700, train loss 0.003327, train error 0.00,  test loss 6.187004, test error 54.05
# Epoch   800, train loss 0.002657, train error 0.00,  test loss 6.397511, test error 54.12
# Epoch   900, train loss 0.002205, train error 0.00,  test loss 6.579425, test error 54.15
# Training model with  70 hidden variables
# Epoch     0, train loss 2.013040, train error 75.22,  test loss 1.933643, test error 75.32
# Epoch   100, train loss 0.394557, train error 10.53,  test loss 1.854721, test error 51.15
# Epoch   200, train loss 0.034409, train error 0.00,  test loss 3.446649, test error 53.10
# Epoch   300, train loss 0.010791, train error 0.00,  test loss 4.242020, test error 53.50
# Epoch   400, train loss 0.005915, train error 0.00,  test loss 4.677469, test error 53.78
# Epoch   500, train loss 0.003960, train error 0.00,  test loss 4.974736, test error 53.72
# Epoch   600, train loss 0.002929, train error 0.00,  test loss 5.200496, test error 53.85
# Epoch   700, train loss 0.002299, train error 0.00,  test loss 5.381306, test error 53.85
# Epoch   800, train loss 0.001877, train error 0.00,  test loss 5.533514, test error 53.70
# Epoch   900, train loss 0.001576, train error 0.00,  test loss 5.666033, test error 53.78
# Training model with  80 hidden variables
# Epoch     0, train loss 2.016271, train error 74.90,  test loss 1.939720, test error 75.93
# Epoch   100, train loss 0.218967, train error 3.12,  test loss 2.151927, test error 52.35
# Epoch   200, train loss 0.019288, train error 0.00,  test loss 3.448543, test error 53.08
# Epoch   300, train loss 0.007999, train error 0.00,  test loss 3.990347, test error 53.08
# Epoch   400, train loss 0.004757, train error 0.00,  test loss 4.321160, test error 52.83
# Epoch   500, train loss 0.003303, train error 0.00,  test loss 4.556633, test error 53.08
# Epoch   600, train loss 0.002499, train error 0.00,  test loss 4.738439, test error 53.28
# Epoch   700, train loss 0.001982, train error 0.00,  test loss 4.886285, test error 53.35
# Epoch   800, train loss 0.001635, train error 0.00,  test loss 5.010551, test error 53.33
# Epoch   900, train loss 0.001385, train error 0.00,  test loss 5.119297, test error 53.28
# Training model with  90 hidden variables
# Epoch     0, train loss 2.005440, train error 74.95,  test loss 1.962015, test error 76.72
# Epoch   100, train loss 0.141656, train error 1.15,  test loss 2.220129, test error 51.50
# Epoch   200, train loss 0.014854, train error 0.00,  test loss 3.294978, test error 52.05
# Epoch   300, train loss 0.006538, train error 0.00,  test loss 3.734200, test error 52.03
# Epoch   400, train loss 0.004005, train error 0.00,  test loss 4.005077, test error 52.08
# Epoch   500, train loss 0.002815, train error 0.00,  test loss 4.200655, test error 52.15
# Epoch   600, train loss 0.002145, train error 0.00,  test loss 4.352691, test error 52.12
# Epoch   700, train loss 0.001715, train error 0.00,  test loss 4.478064, test error 52.38
# Epoch   800, train loss 0.001420, train error 0.00,  test loss 4.583948, test error 52.45
# Epoch   900, train loss 0.001207, train error 0.00,  test loss 4.675831, test error 52.55
# Training model with 100 hidden variables
# Epoch     0, train loss 1.982541, train error 73.28,  test loss 1.912243, test error 72.03
# Epoch   100, train loss 0.092226, train error 0.18,  test loss 2.342803, test error 51.78
# Epoch   200, train loss 0.012207, train error 0.00,  test loss 3.268269, test error 51.45
# Epoch   300, train loss 0.005641, train error 0.00,  test loss 3.655964, test error 51.70
# Epoch   400, train loss 0.003508, train error 0.00,  test loss 3.899426, test error 51.72
# Epoch   500, train loss 0.002492, train error 0.00,  test loss 4.076021, test error 51.67
# Epoch   600, train loss 0.001906, train error 0.00,  test loss 4.214379, test error 51.72
# Epoch   700, train loss 0.001531, train error 0.00,  test loss 4.328863, test error 51.70
# Epoch   800, train loss 0.001272, train error 0.00,  test loss 4.427194, test error 51.75
# Epoch   900, train loss 0.001083, train error 0.00,  test loss 4.510860, test error 51.70
# Training model with 120 hidden variables
# Epoch     0, train loss 1.975906, train error 73.35,  test loss 1.938277, test error 74.15
# Epoch   100, train loss 0.051731, train error 0.00,  test loss 2.233459, test error 51.50
# Epoch   200, train loss 0.009482, train error 0.00,  test loss 2.846058, test error 51.33
# Epoch   300, train loss 0.004681, train error 0.00,  test loss 3.124930, test error 51.28
# Epoch   400, train loss 0.002994, train error 0.00,  test loss 3.307894, test error 51.28
# Epoch   500, train loss 0.002161, train error 0.00,  test loss 3.442392, test error 51.40
# Epoch   600, train loss 0.001671, train error 0.00,  test loss 3.547925, test error 51.20
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.635594, test error 51.17
# Epoch   800, train loss 0.001128, train error 0.00,  test loss 3.709609, test error 51.33
# Epoch   900, train loss 0.000964, train error 0.00,  test loss 3.775410, test error 51.17
# Training model with 140 hidden variables
# Epoch     0, train loss 1.958130, train error 72.03,  test loss 1.900055, test error 73.12
# Epoch   100, train loss 0.037076, train error 0.00,  test loss 2.265765, test error 50.10
# Epoch   200, train loss 0.008071, train error 0.00,  test loss 2.779237, test error 49.62
# Epoch   300, train loss 0.004140, train error 0.00,  test loss 3.025811, test error 50.10
# Epoch   400, train loss 0.002688, train error 0.00,  test loss 3.184568, test error 49.97
# Epoch   500, train loss 0.001957, train error 0.00,  test loss 3.303123, test error 50.10
# Epoch   600, train loss 0.001522, train error 0.00,  test loss 3.397829, test error 50.20
# Epoch   700, train loss 0.001236, train error 0.00,  test loss 3.476808, test error 50.20
# Epoch   800, train loss 0.001035, train error 0.00,  test loss 3.543971, test error 50.10
# Epoch   900, train loss 0.000887, train error 0.00,  test loss 3.602811, test error 50.10
# Training model with 160 hidden variables
# Epoch     0, train loss 1.922987, train error 71.00,  test loss 1.840816, test error 71.35
# Epoch   100, train loss 0.028398, train error 0.00,  test loss 2.077714, test error 48.92
# Epoch   200, train loss 0.007108, train error 0.00,  test loss 2.461963, test error 49.00
# Epoch   300, train loss 0.003759, train error 0.00,  test loss 2.651461, test error 48.85
# Epoch   400, train loss 0.002473, train error 0.00,  test loss 2.775885, test error 49.00
# Epoch   500, train loss 0.001811, train error 0.00,  test loss 2.869997, test error 48.95
# Epoch   600, train loss 0.001415, train error 0.00,  test loss 2.945292, test error 48.83
# Epoch   700, train loss 0.001153, train error 0.00,  test loss 3.007982, test error 48.78
# Epoch   800, train loss 0.000968, train error 0.00,  test loss 3.062088, test error 48.75
# Epoch   900, train loss 0.000831, train error 0.00,  test loss 3.108808, test error 48.60
# Training model with 180 hidden variables
# Epoch     0, train loss 1.933366, train error 71.82,  test loss 1.872381, test error 73.05
# Epoch   100, train loss 0.023763, train error 0.00,  test loss 2.181307, test error 49.88
# Epoch   200, train loss 0.006512, train error 0.00,  test loss 2.565795, test error 49.72
# Epoch   300, train loss 0.003494, train error 0.00,  test loss 2.757255, test error 49.67
# Epoch   400, train loss 0.002319, train error 0.00,  test loss 2.886711, test error 49.60
# Epoch   500, train loss 0.001709, train error 0.00,  test loss 2.982570, test error 49.58
# Epoch   600, train loss 0.001339, train error 0.00,  test loss 3.059877, test error 49.65
# Epoch   700, train loss 0.001093, train error 0.00,  test loss 3.124887, test error 49.67
# Epoch   800, train loss 0.000919, train error 0.00,  test loss 3.180297, test error 49.67
# Epoch   900, train loss 0.000790, train error 0.00,  test loss 3.229141, test error 49.70
# Training model with 200 hidden variables
# Epoch     0, train loss 1.920658, train error 70.85,  test loss 1.834999, test error 71.30
# Epoch   100, train loss 0.021475, train error 0.00,  test loss 2.030633, test error 47.70
# Epoch   200, train loss 0.006147, train error 0.00,  test loss 2.354159, test error 47.85
# Epoch   300, train loss 0.003331, train error 0.00,  test loss 2.522531, test error 47.67
# Epoch   400, train loss 0.002218, train error 0.00,  test loss 2.634263, test error 47.55
# Epoch   500, train loss 0.001640, train error 0.00,  test loss 2.718770, test error 47.58
# Epoch   600, train loss 0.001287, train error 0.00,  test loss 2.786358, test error 47.62
# Epoch   700, train loss 0.001053, train error 0.00,  test loss 2.842640, test error 47.58
# Epoch   800, train loss 0.000886, train error 0.00,  test loss 2.891182, test error 47.55
# Epoch   900, train loss 0.000763, train error 0.00,  test loss 2.933975, test error 47.53
# Training model with 250 hidden variables
# Epoch     0, train loss 1.880414, train error 68.68,  test loss 1.804103, test error 70.45
# Epoch   100, train loss 0.016535, train error 0.00,  test loss 1.914297, test error 47.20
# Epoch   200, train loss 0.005225, train error 0.00,  test loss 2.160328, test error 46.75
# Epoch   300, train loss 0.002918, train error 0.00,  test loss 2.290807, test error 46.58
# Epoch   400, train loss 0.001972, train error 0.00,  test loss 2.381709, test error 46.75
# Epoch   500, train loss 0.001470, train error 0.00,  test loss 2.450868, test error 46.85
# Epoch   600, train loss 0.001161, train error 0.00,  test loss 2.506443, test error 46.85
# Epoch   700, train loss 0.000954, train error 0.00,  test loss 2.553113, test error 46.72
# Epoch   800, train loss 0.000806, train error 0.00,  test loss 2.593783, test error 46.67
# Epoch   900, train loss 0.000696, train error 0.00,  test loss 2.629370, test error 46.67
# Training model with 300 hidden variables
# Epoch     0, train loss 1.895438, train error 68.68,  test loss 1.815231, test error 70.20
# Epoch   100, train loss 0.014713, train error 0.00,  test loss 1.863856, test error 46.33
# Epoch   200, train loss 0.004852, train error 0.00,  test loss 2.075965, test error 45.95
# Epoch   300, train loss 0.002741, train error 0.00,  test loss 2.187986, test error 45.90
# Epoch   400, train loss 0.001867, train error 0.00,  test loss 2.266840, test error 45.92
# Epoch   500, train loss 0.001397, train error 0.00,  test loss 2.328701, test error 45.88
# Epoch   600, train loss 0.001106, train error 0.00,  test loss 2.377806, test error 45.78
# Epoch   700, train loss 0.000911, train error 0.00,  test loss 2.419889, test error 45.75
# Epoch   800, train loss 0.000771, train error 0.00,  test loss 2.455189, test error 45.83
# Epoch   900, train loss 0.000666, train error 0.00,  test loss 2.487331, test error 45.80
# Training model with 400 hidden variables
# Epoch     0, train loss 1.849310, train error 66.25,  test loss 1.788905, test error 68.43
# Epoch   100, train loss 0.011873, train error 0.00,  test loss 1.658158, test error 44.85
# Epoch   200, train loss 0.004220, train error 0.00,  test loss 1.818215, test error 44.80
# Epoch   300, train loss 0.002440, train error 0.00,  test loss 1.907795, test error 44.70
# Epoch   400, train loss 0.001679, train error 0.00,  test loss 1.971055, test error 44.78
# Epoch   500, train loss 0.001264, train error 0.00,  test loss 2.018579, test error 44.85
# Epoch   600, train loss 0.001006, train error 0.00,  test loss 2.057477, test error 44.78
# Epoch   700, train loss 0.000831, train error 0.00,  test loss 2.090814, test error 44.70
# Epoch   800, train loss 0.000705, train error 0.00,  test loss 2.119398, test error 44.67
# Epoch   900, train loss 0.000611, train error 0.00,  test loss 2.144365, test error 44.65

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
